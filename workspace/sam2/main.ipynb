# %%
from ultralytics import SAM

# %%
# Load a model
model = SAM(model="sam2.1_b.pt")
model.info()
# Out:
# Model summary: 436 layers, 80,850,178 parameters, 80,850,178 gradients
# (436, 80850178, 80850178, 0.0)

# %%
# Run inference
model("path/to/video.mp4")
